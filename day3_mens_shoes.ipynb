# %%
# !pip install datadotworld
# !pip install datadotworld[pandas]
# Out:
# ...
#      |████████████████████████████████| 163kB 2.9MB/s
# ...
#      |████████████████████████████████| 71kB 9.3MB/s
# ...
#      |████████████████████████████████| 71kB 10.4MB/s
# ...
#      |████████████████████████████████| 92kB 12.2MB/s
# ...
#      |████████████████████████████████| 71kB 9.8MB/s
# ...
#      |████████████████████████████████| 51kB 7.5MB/s
# ...
#      |████████████████████████████████| 174kB 56.9MB/s
# ...
#      |████████████████████████████████| 245kB 51.0MB/s
# ...
#      |████████████████████████████████| 71kB 10.0MB/s
# ...
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-cp36-none-any.whl size=10768 sha256=5e50f2d9598a724b1803e241fb1d7be367c2238ddf51b3692757b68a360ef73a
#   Stored in directory: /root/.cache/pip/wheels/a6/09/e9/e800279c98a0a8c94543f3de6c8a562f60e51363ed26e71283
# ...
#   Created wheel for openpyxl: filename=openpyxl-3.0.3-py2.py3-none-any.whl size=241262 sha256=be2b72973fd0b8aa01a8940d58be50bd9f981dfa02ff43754586b1f96440f671
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !dw configure
# Out:
# API token (obtained at: https://data.world/settings/advanced): eyJhbGciOiJIUzUxMiJ9..CjyzYn3HD6_N20W76P9M7S2fzUw7yg81l_y4XfsT6-DJpTOlnVwd-pEGfpENA9ghdKCIpZvlWqYsBphgT-d-uA

# %%
from google.colab import drive
import pandas as pd
import numpy as np

import datadotworld as dw

# %%
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd "drive/My Drive/Colab Notebooks/dw_matrix"
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix

# %%
# !mkdir data

# %%
# !echo 'data' > .gitignore #ignore all the changes in git catalogue data

# %%
# !git add .gitignore

# %%
data = dw.load_dataset('datafiniti/mens-shoe-prices')

# %%
df = data.dataframes['7004_1']
df.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/datadotworld/models/dataset.py:209: UserWarning: Unable to set data frame dtypes automatically using 7004_1 schema. Data types may need to be adjusted manually. Error: Integer column has NA values in column 10
#   'Error: {}'.format(resource_name, e))
# /usr/local/lib/python3.6/dist-packages/datadotworld/util.py:121: DtypeWarning: Columns (39,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return self._loader_func()
# (19387, 48)

# %%
df.sample(5)
# Out:
#                          id                             asins  ... websiteids weight
# 3926   AVpe_fF2LJeJML43z-RT                               NaN  ...        NaN    NaN
# 2393   AVpfBOAcilAPnD_xTJ-W                               NaN  ...        NaN    NaN
# 7919   AVpfN37A1cnluZ0-gYxC                               NaN  ...        NaN    NaN
# 11022  AVpfKZQj1cnluZ0-fPmj                        B00WOURKM0  ...        NaN   7 Kg
# 6225   AVpe8MfdLJeJML43yy3B  B01AQ260SM,B01AQ25X7G,B01AQ25Z4C  ...        NaN    NaN
#
# [5 rows x 48 columns]

# %%
df.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'count', 'dateadded',
#        'dateupdated', 'descriptions', 'dimension', 'ean', 'features',
#        'flavors', 'imageurls', 'isbn', 'keys', 'manufacturer',
#        'manufacturernumber', 'merchants', 'name', 'prices_amountmin',
#        'prices_amountmax', 'prices_availability', 'prices_color',
#        'prices_condition', 'prices_count', 'prices_currency',
#        'prices_dateadded', 'prices_dateseen', 'prices_flavor', 'prices_issale',
#        'prices_merchant', 'prices_offer', 'prices_returnpolicy',
#        'prices_shipping', 'prices_size', 'prices_source', 'prices_sourceurls',
#        'prices_warranty', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceurls', 'upc', 'vin', 'websiteids', 'weight'],
#       dtype='object')

# %%
df.prices_currency.unique()
# Out:
# array(['USD', 'AUD', 'CAD', 'EUR', nan, 'GBP', 'New with box',
#        'UnbeatableSale.com, Inc. - Walmart.com',
#        'PalmBeach Jewelry - Walmart.com', 'new', 'New without tags',
#        'SHOEBACCA LTD. - Walmart.com', 'Shoes.com',
#        'Wholesale Costume and Party Supplies - Walmart.com'], dtype=object)

# %%
df.prices_currency.value_counts(normalize=True)
# Out:
# USD                                                   0.959246
# AUD                                                   0.017503
# CAD                                                   0.015691
# EUR                                                   0.005541
# GBP                                                   0.001139
# New with box                                          0.000155
# new                                                   0.000155
# PalmBeach Jewelry - Walmart.com                       0.000155
# UnbeatableSale.com, Inc. - Walmart.com                0.000155
# Wholesale Costume and Party Supplies - Walmart.com    0.000104
# Shoes.com                                             0.000052
# New without tags                                      0.000052
# SHOEBACCA LTD. - Walmart.com                          0.000052
# Name: prices_currency, dtype: float64

# %%
# rows with USD - filter
df_usd = df[df.prices_currency == 'USD'].copy()
df_usd.shape
# Out:
# (18524, 48)

# %%
df_usd['prices_amountmin']= df_usd.prices_amountmin.astype(np.float)
df_usd['prices_amountmin'].hist()

# %%
# normalizing - max cap
filter_max = np.percentile( df_usd['prices_amountmin'], 99)
filter_max
# Out:
# 895.0

# %%
df_usd_filter = df_usd[df_usd['prices_amountmin'] < filter_max]

# %%
df_usd_filter.prices_amountmin.hist(bins=100)

# %%
df.to_csv('data/shoes_prices.csv', index=False)

# %%
# !git add data/day3_mens_shoes.ipynb

# %%
# !git commit -m "Read Men's Shoe Prices dataset from data.word"

# %%
# !git push -u origin master

# %%
# !git config --global user.email "tischencko.el@gmail.com"
# !git config --global user.name "Elizabeth"
